# %%
from bauer.utils.data import load_garcia2022
import numpy as np

# %%
df = load_garcia2022()

# %%
df['correct'] = (df['log(n2/n1)'] > 0)
# Out:
#   Cell In[37], line 1
#     df['correct'] = (df['log(n2/n1)'] > 0) == df[]
#                                                  ^
# SyntaxError: invalid syntax

# %%
(df.leftright == -2).sum()
# Out:
# 68

# %%
df.loc[df.leftright == -2, 'correct'] = np.nan

# %%
df['choice'].isnull().any()
# Out:
# False

# %%
df.to_csv('~/git/bauer/bauer/data/garcia2022.csv')

# %%
df.groupby(['log(n2/n1)']).mean()['correct'].plot()
# Out:
# <Axes: xlabel='log(n2/n1)'>
